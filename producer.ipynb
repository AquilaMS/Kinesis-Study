# %%
import requests
import random as rd 
import time
import boto3
import json
import os

#gets the api keys from OS enviroment variables
access_key = os.environ.get('AWS_ACCESS_KEY')
secret_key = os.environ.get('AWS_ACCESS_SECRET_KEY')
stream_name ='myTestStream'
fake_user_api_url = 'https://randomuser.me/api/'

#loads kinesis client with keys
client = boto3.client(
    'kinesis',
    aws_access_key_id = access_key, 
    aws_secret_access_key = secret_key, 
    region_name = 'us-east-1')

def get_data():
    response_user = requests.get(fake_user_api_url).json()
    response_user_results = response_user['results'][0]

    user_name = response_user_results['name']['first'] + ' ' + response_user_results['name']['last']
    user_city = response_user_results['location']['city']
    pointsMade = rd.randrange(1,200)
    #sends generated datas to be sent in points_data 
    points_data(user_name, user_city, pointsMade)

def points_data(name, city, points):

    points_data = {
        'name': name,
        'city': city,
        'points': points,
    }

    client.put_record(
        StreamName = stream_name,
        Data = json.dumps(points_data),
        PartitionKey = '02'
    )
    
    print(points_data)

while True:
    get_data()
    time.sleep(0.3)
# Out:
# {'name': 'Mangala Bal', 'city': 'Rohtak', 'points': 15}
# {'name': 'Idhant Raval', 'city': 'Singrauli', 'points': 158}
# {'name': 'Milomir Srejović', 'city': 'Surdulica', 'points': 110}
# {'name': 'Elias Giraud', 'city': 'Rueil-Malmaison', 'points': 197}
# {'name': 'Maxine Elliott', 'city': 'Bathurst', 'points': 72}
# {'name': 'Emmi Kangas', 'city': 'Ruokolahti', 'points': 14}
# {'name': 'Lucien Martinez', 'city': 'Besançon', 'points': 181}
# {'name': 'Alejandro Toro', 'city': 'Hernández', 'points': 82}
# {'name': 'Oliver Hakola', 'city': 'Hämeenkyrö', 'points': 34}
# {'name': 'Philip Chow', 'city': 'Princeton', 'points': 160}
# {'name': 'Patricio Casanova', 'city': 'Papaloapam', 'points': 95}
# {'name': 'محمدامين سلطانی نژاد', 'city': 'رشت', 'points': 53}
# {'name': 'Virgill Leppers', 'city': 'Oudesluis', 'points': 36}
# {'name': 'دینا زارعی', 'city': 'شیراز', 'points': 174}
# {'name': 'Lonnie Williamson', 'city': 'Adelaide', 'points': 173}
# {'name': 'Kora Haritonenko', 'city': 'Novodruzhesk', 'points': 28}
# {'name': 'Toby Zhang', 'city': 'Hastings', 'points': 66}
# {'name': 'Eemeli Ahola', 'city': 'Lemland', 'points': 131}
# {'name': 'Samuel Adams', 'city': 'Cleveland', 'points': 185}
# {'name': 'Carmen Calvillo', 'city': 'La Ventosa', 'points': 68}
# {'name': 'Krin Reid', 'city': 'Albury', 'points': 65}
# {'name': 'Michèle Henry', 'city': 'Prilly', 'points': 88}
# {'name': 'Hemang Bangera', 'city': 'Mahbubnagar', 'points': 66}
# {'name': 'Katalina Bjelica', 'city': 'Trstenik', 'points': 185}
# {'name': 'Solano Pereira', 'city': 'Suzano', 'points': 11}
# {'name': 'Massimiliano Colin', 'city': 'Zollikofen', 'points': 11}
# {'name': 'عسل رضاییان', 'city': 'تبریز', 'points': 116}
# {'name': 'Vanesa Álvarez', 'city': 'Bilbao', 'points': 60}
# {'name': 'Dylan Taylor', 'city': 'Auckland', 'points': 61}
# {'name': 'Lina Menard', 'city': 'Fort-de-France', 'points': 47}
# {'name': 'Ilham Heezen', 'city': 'Nieuweroord', 'points': 184}
# {'name': 'Begüm Taşlı', 'city': 'Bayburt', 'points': 181}
# {'name': 'مارال نجاتی', 'city': 'ارومیه', 'points': 88}
# {'name': 'Yasemin Dağdaş', 'city': 'Samsun', 'points': 192}
# {'name': 'Gunhild Langenbach', 'city': 'Bitburg-Prüm', 'points': 127}
# {'name': 'Bilal Hasan', 'city': 'Grimstad', 'points': 192}
# {'name': 'Stephanie Farragher', 'city': 'Monaghan', 'points': 88}
# {'name': 'Bhuv Almeida', 'city': 'Saharsa', 'points': 124}
# {'name': 'کیمیا سالاری', 'city': 'بجنورد', 'points': 13}
# {'name': 'Emilia Jutila', 'city': 'Vieremä', 'points': 2}
# {'name': 'Xiomara Campos', 'city': 'Várzea Grande', 'points': 145}
# {'name': 'Andrea Tejada', 'city': 'Ixtapa Zihuatanejo', 'points': 183}
# {'name': 'Théo Martinez', 'city': 'Oberentfelden', 'points': 99}
# {'name': 'Naksh Bhoja', 'city': 'Pali', 'points': 23}
# {'name': 'Adrian Ray', 'city': 'Seattle', 'points': 130}
# {'name': 'Melitina Arsenich', 'city': 'Belz', 'points': 122}
# {'name': 'Soham Bradley', 'city': 'Dublin', 'points': 163}
# {'name': 'Rishaan Belligatti', 'city': 'Firozabad', 'points': 165}
# {'name': 'Ceciliya Sviridenko', 'city': 'Zvenigorodka', 'points': 63}
# {'name': 'Perry Turner', 'city': 'Cardiff', 'points': 51}
# {'name': 'Terentiy Bilecka', 'city': 'Uzhgorod', 'points': 178}
# {'name': 'Karla Kristensen', 'city': 'Gørløse', 'points': 165}
# {'name': 'Alexis Marchand', 'city': 'Nîmes', 'points': 39}
# {'name': 'Nadia Manzanares', 'city': 'La Norteña', 'points': 128}
# {'name': 'Silje Christensen', 'city': 'Agerbæk', 'points': 189}
# {'name': 'Nicolai Becher', 'city': 'Münsingen', 'points': 180}
# {'name': 'Utkarsh Dawangave', 'city': 'Udaipur', 'points': 67}
# {'name': 'Advaith Dalvi', 'city': 'Vijayawada', 'points': 93}
# {'name': 'Aapo Koskinen', 'city': 'Saltvik', 'points': 113}
# {'name': 'Ceyhan Abanuz', 'city': 'Sakarya', 'points': 84}
# {'name': 'Bérénice Girard', 'city': 'Strasbourg', 'points': 23}
# {'name': 'Kenneth Stone', 'city': 'Carrollton', 'points': 101}
# {'name': 'Ellie Carter', 'city': 'Carrick-on-Shannon', 'points': 95}
# {'name': 'Maëline Chevalier', 'city': 'Créteil', 'points': 134}
# {'name': 'Marise Damen', 'city': 'Millingen A/D Rijn', 'points': 7}
# {'name': 'Isandro Dias', 'city': 'Uberaba', 'points': 194}
# {'name': 'Rouven Husmann', 'city': 'Brakel', 'points': 133}
# {'name': 'Kay Walters', 'city': 'Thousand Oaks', 'points': 88}
# {'name': 'Emile Smith', 'city': 'Hampstead', 'points': 81}
# {'name': 'Eliot Bertrand', 'city': 'Argenteuil', 'points': 162}
# {'name': 'Carolyn Gregory', 'city': 'Gorey', 'points': 36}
# {'name': 'Lucia Domínguez', 'city': 'Elche', 'points': 139}
# {'name': 'Renuka Prabhu', 'city': 'North Dumdum', 'points': 119}
# {'name': 'Hebe Van Acker', 'city': 'Rijnsburg', 'points': 191}
# {'name': 'Fritz Schiele', 'city': 'Köthen (Anhalt)', 'points': 160}
# {'name': 'Dwayne Pearson', 'city': 'Devonport', 'points': 85}
# {'name': 'Andreas Pedersen', 'city': 'Ulsted, Hals', 'points': 154}
# {'name': 'Milica Mitrović', 'city': 'Vrbas', 'points': 89}
# {'name': 'Pavle Stojković', 'city': 'Vladičin Han', 'points': 180}
# {'name': 'Ricardo Ramos', 'city': 'Londonderry', 'points': 175}
# {'name': 'Supriya Banerjee', 'city': 'Muzaffarpur', 'points': 113}
# {'name': 'Ananya Prabhu', 'city': 'Kalyan-Dombivli', 'points': 189}
# {'name': 'Aldo Báez', 'city': 'Macultepec-Ocuiltzapotlan', 'points': 144}
# {'name': 'Leonard Bailey', 'city': 'Bristol', 'points': 39}
# {'name': 'Elle Kronstad', 'city': 'Moss', 'points': 68}
# {'name': 'Iván Fajardo', 'city': 'Ejido Guadalajara', 'points': 107}
# {'name': 'Momir Šijan', 'city': 'Brus', 'points': 138}
# {'name': 'Alexandre Mitchell', 'city': 'Keswick', 'points': 182}
# {'name': 'Ninon Chevalier', 'city': 'Saint-Étienne', 'points': 69}
# {'name': 'Alicia Olmos', 'city': 'Amatitán', 'points': 121}
# {'name': 'Stephan Guillaume', 'city': 'Reisiswil', 'points': 103}
# {'name': 'Chad Richards', 'city': 'Wells', 'points': 181}
# {'name': 'Selene da Conceição', 'city': 'Eunápolis', 'points': 123}
# {'name': 'Selma Andersen', 'city': 'Stokkemarke', 'points': 14}
# {'name': 'Mirjana Pierre', 'city': 'Morrens (Vd)', 'points': 138}
# {'name': 'Bertram Jørgensen', 'city': 'Haslev', 'points': 39}
# {'name': 'Nishitha Sheikh', 'city': 'Kulti', 'points': 140}
# {'name': 'Aubree Campbell', 'city': 'Minto', 'points': 175}
# {'name': 'Vergílio Rodrigues', 'city': 'Poá', 'points': 34}
# {'name': 'نازنین مرادی', 'city': 'اهواز', 'points': 51}
# {'name': 'Léo Noel', 'city': 'Pau', 'points': 132}
# {'name': 'Janet Hunt', 'city': 'Albury', 'points': 146}
# {'name': 'Özkan Çapanoğlu', 'city': 'Muş', 'points': 9}
# {'name': 'مارال قاسمی', 'city': 'ورامین', 'points': 97}
# {'name': 'Sean Soto', 'city': 'Adelaide', 'points': 177}
# {'name': 'Emma Pedersen', 'city': 'Viby Sj.', 'points': 154}
# {'name': 'David Anderson', 'city': 'Dunedin', 'points': 191}
